# %% [markdown]
# echo "# Capstone_project" >> README.md
# git init
# git add README.md
# git commit -m "first commit"
# git branch -M main
# git remote add origin https://github.com/OyebolaS/Capstone_project.git
# git push -u origin main

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\DELL 5480\Desktop\final project\Final Project\call log.csv')

# %%
df2 = pd.read_csv(r'C:\Users\DELL 5480\Desktop\final project\Final Project\call details.csv')

# %%
df
# Out:
#       id    callerID  agentID                        complaintTopic  \
# 0      1    CALLER_1      163                   Billing discrepancy
# 1      2    CALLER_2      133  Difficulty reaching customer support
# 2      3    CALLER_3      153                   Wrong item received
# 3      4    CALLER_4      161                  Unauthorized charges
# 4      5    CALLER_5      148               Unprofessional behavior
# ..   ...         ...      ...                                   ...
# 595  596  CALLER_596      137                     Unhelpful support
# 596  597  CALLER_597      159                    Slow response time
# 597  598  CALLER_598      148                        Shipping delay
# 598  599  CALLER_599      161                   Website not working
# 599  600  CALLER_600      127                   Wrong item received
#
#      assignedTo    status  resolutionDurationInHours
# 0         122.0    CLOSED                       33.0
# ...

# %%
df2
# Out:
#                 callID  callDurationInSeconds agentsGradeLevel  callType  \
# 0    ageentsGradeLevel                     97                A   Inbound
# 1                    2                     64                E  in-bound
# 2                    3                    100                C  in-bound
# 3                    4                     69                D  Outbound
# 4                    5                     96                D   Inbound
# ..                 ...                    ...              ...       ...
# 595                596                    147                E  Outbound
# 596                597                     90                A  in-bound
# 597                598                     89                F  Outbound
# 598                599                    146                D   Inbound
# 599                600                    103                C  Outbound
#
#      callEndedByAgent
# 0               False
# 1                True
# ...

# %%
#capitalize !st letters in status column
df['status']= df['status'].str.lower().str.capitalize()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         600 non-null    int64
#  1   callerID                   600 non-null    object
#  2   agentID                    600 non-null    int64
#  3   complaintTopic             600 non-null    object
#  4   assignedTo                 372 non-null    float64
#  5   status                     600 non-null    object
#  6   resolutionDurationInHours  187 non-null    float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 32.9+ KB

# %%
#fill missing assignedTo values with agentID where missing
for i in df.values:
    df['assignedTo']=df['assignedTo'].fillna(df['agentID'])

# %%
df
# Out:
#       id    callerID  agentID                        complaintTopic  \
# 0      1    CALLER_1      163                   Billing discrepancy
# 1      2    CALLER_2      133  Difficulty reaching customer support
# 2      3    CALLER_3      153                   Wrong item received
# 3      4    CALLER_4      161                  Unauthorized charges
# 4      5    CALLER_5      148               Unprofessional behavior
# ..   ...         ...      ...                                   ...
# 595  596  CALLER_596      137                     Unhelpful support
# 596  597  CALLER_597      159                    Slow response time
# 597  598  CALLER_598      148                        Shipping delay
# 598  599  CALLER_599      161                   Website not working
# 599  600  CALLER_600      127                   Wrong item received
#
#      assignedTo    status  resolutionDurationInHours
# 0         122.0    Closed                       33.0
# ...

# %%
#changing the datatype from float to integer for assignedTo column
df['assignedTo']= df['assignedTo'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         600 non-null    int64
#  1   callerID                   600 non-null    object
#  2   agentID                    600 non-null    int64
#  3   complaintTopic             600 non-null    object
#  4   assignedTo                 600 non-null    int32
#  5   status                     600 non-null    object
#  6   resolutionDurationInHours  187 non-null    float64
# dtypes: float64(1), int32(1), int64(2), object(3)
# memory usage: 30.6+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         600 non-null    int64
#  1   callerID                   600 non-null    object
#  2   agentID                    600 non-null    int64
#  3   complaintTopic             600 non-null    object
#  4   assignedTo                 600 non-null    int32
#  5   status                     600 non-null    object
#  6   resolutionDurationInHours  187 non-null    float64
# dtypes: float64(1), int32(1), int64(2), object(3)
# memory usage: 30.6+ KB

# %%
 #filling blank rows in resolutionDurationInHours column
df.resolutionDurationInHours =  df.resolutionDurationInHours.fillna('Not provided')

# %%
df
# Out:
#       id    callerID  agentID                        complaintTopic  \
# 0      1    CALLER_1      163                   Billing discrepancy
# 1      2    CALLER_2      133  Difficulty reaching customer support
# 2      3    CALLER_3      153                   Wrong item received
# 3      4    CALLER_4      161                  Unauthorized charges
# 4      5    CALLER_5      148               Unprofessional behavior
# ..   ...         ...      ...                                   ...
# 595  596  CALLER_596      137                     Unhelpful support
# 596  597  CALLER_597      159                    Slow response time
# 597  598  CALLER_598      148                        Shipping delay
# 598  599  CALLER_599      161                   Website not working
# 599  600  CALLER_600      127                   Wrong item received
#
#      assignedTo    status resolutionDurationInHours
# 0           122    Closed                      33.0
# ...

# %%
#REMOVING DUPLICATES IN CALL LOG TABLE
df.T.drop_duplicates().T
# Out:
#       id    callerID agentID                        complaintTopic assignedTo  \
# 0      1    CALLER_1     163                   Billing discrepancy        122
# 1      2    CALLER_2     133  Difficulty reaching customer support        133
# 2      3    CALLER_3     153                   Wrong item received        122
# 3      4    CALLER_4     161                  Unauthorized charges        151
# 4      5    CALLER_5     148               Unprofessional behavior        148
# ..   ...         ...     ...                                   ...        ...
# 595  596  CALLER_596     137                     Unhelpful support        169
# 596  597  CALLER_597     159                    Slow response time        159
# 597  598  CALLER_598     148                        Shipping delay        150
# 598  599  CALLER_599     161                   Website not working        148
# 599  600  CALLER_600     127                   Wrong item received        149
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   callID                 600 non-null    object
#  1   callDurationInSeconds  600 non-null    int64
#  2   agentsGradeLevel       600 non-null    object
#  3   callType               600 non-null    object
#  4   callEndedByAgent       600 non-null    bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 19.5+ KB

# %%
df2.T.drop_duplicates().T
# Out:
#                 callID callDurationInSeconds agentsGradeLevel  callType  \
# 0    ageentsGradeLevel                    97                A   Inbound
# 1                    2                    64                E  in-bound
# 2                    3                   100                C  in-bound
# 3                    4                    69                D  Outbound
# 4                    5                    96                D   Inbound
# ..                 ...                   ...              ...       ...
# 595                596                   147                E  Outbound
# 596                597                    90                A  in-bound
# 597                598                    89                F  Outbound
# 598                599                   146                D   Inbound
# 599                600                   103                C  Outbound
#
#     callEndedByAgent
# 0              False
# 1               True
# 2              False
# ...

# %%
#changing the value of 1st row in callID column
df2.at[0,'callID']='1'

# %%
df2
# Out:
#     callID  callDurationInSeconds agentsGradeLevel  callType  callEndedByAgent
# 0        1                     97                A   Inbound             False
# 1        2                     64                E  in-bound              True
# 2        3                    100                C  in-bound             False
# 3        4                     69                D  Outbound              True
# 4        5                     96                D   Inbound              True
# ..     ...                    ...              ...       ...               ...
# 595    596                    147                E  Outbound              True
# 596    597                     90                A  in-bound              True
# 597    598                     89                F  Outbound              True
# 598    599                    146                D   Inbound             False
# 599    600                    103                C  Outbound             False
#
# [600 rows x 5 columns]

# %%
df2['callID']= df2['callID'].astype(int)

# %%
#capitalize !st letters in callType column and removing - in inbound
df2['callType']= df2['callType'].str.lower().str.capitalize()
df2['callType']= df2['callType'].str.replace('-', '')

# %%
df2
# Out:
#      callID  callDurationInSeconds agentsGradeLevel  callType  \
# 0         1                     97                A   Inbound
# 1         2                     64                E   Inbound
# 2         3                    100                C   Inbound
# 3         4                     69                D  Outbound
# 4         5                     96                D   Inbound
# ..      ...                    ...              ...       ...
# 595     596                    147                E  Outbound
# 596     597                     90                A   Inbound
# 597     598                     89                F  Outbound
# 598     599                    146                D   Inbound
# 599     600                    103                C  Outbound
#
#      callEndedByAgent
# 0               False
# 1                True
# 2               False
# 3                True
# 4                True
# ..                ...
# 595              True
# 596              True
# ...

# %%
df['assigned_calls_to_agent_id'] = df['assignedTo'].copy()

# %%
df['assigned_calls_to_agent_id'] = df['assignedTo'].copy()

# %%
df.to_csv ('cleaned_call_log.csv')
df2.to_csv('cleaned_call_details.csv')
